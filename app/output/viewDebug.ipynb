# %%
import pandas as pd

# %%
# !ls queries
# Out:
# src_475-star__dst_475-511.parquet

# %%
# url1 = "./queries/src_475-star__dst_475-511.parquet"
url1 = "./queries/src_475-484-475-star__dst_475-511-star.parquet"
# url1 = "./queries/src_475-484-475__dst_475-511.parquet"
# Import a parquet file as a pandas DataFrame
df = pd.read_parquet(url1)

# %%
df.head(10)
# Out:
# Empty DataFrame
# Columns: [observation_start(t0), observation_end, prediction_start, prediction_end, observation_events, prediction_events]
# Index: []

# %%
df.shape
# Out:
# (69, 6)
